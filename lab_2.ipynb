# %% [markdown]
# <a href="https://colab.research.google.com/github/Abiliger/IAVD_lab/blob/main/lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Імпорт бібліотек
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis
from sklearn.datasets import load_wine

# %%
# Завантаження другого датасету (Climate Change Data) з Datahub.io
climate_data_url = "https://datahub.io/core/co2-ppm/r/co2-mm-mlo.csv"
df_climate = pd.read_csv(climate_data_url)

# %%
df_wine.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
mean_calls_charge = df_wine['alcohol'].mean()
median_calls_charge = np.median(df_wine['alcohol'])
std_deviation_calls_charge = np.std(df_wine['alcohol'])
variance_calls_charge = np.var(df_wine['alcohol'])
skewness_calls_charge = skew(df_wine['alcohol'])
kurt_calls_charge = kurtosis(df_wine['alcohol'])
min_value_calls_charge = min(df_wine['alcohol'])
max_value_calls_charge = max(df_wine['alcohol'])
range_value_calls_charge = max_value_calls_charge - min_value_calls_charge
coefficient_of_variation_calls_charge = (std_deviation_calls_charge /
mean_calls_charge) * 100
print("Математичне сподівання:",mean_calls_charge)
print("Медіана:",median_calls_charge)
print("Середньоквадратичного відхилення:",std_deviation_calls_charge)
print("Дисперсія:",variance_calls_charge)
print("Коефіцієнт асиметрії:",skewness_calls_charge)
print("Коефіцієнт ексцесу:",kurt_calls_charge)
print("Мінімальне вибіркове значення:",min_value_calls_charge)
print("Максимальне вибіркове значення:",max_value_calls_charge)
print("Розмах:",range_value_calls_charge)
print("Коефіцієнт варіації",coefficient_of_variation_calls_charge)
# Out:
# Математичне сподівання: 13.00061797752809
# Медіана: 13.05
# Середньоквадратичного відхилення: 0.809542914528517
# Дисперсія: 0.6553597304633259
# Коефіцієнт асиметрії: -0.05104747165391963
# Коефіцієнт ексцесу: -0.8622600987701743
# Мінімальне вибіркове значення: 11.03
# Максимальне вибіркове значення: 14.83
# Розмах: 3.8000000000000007
# Коефіцієнт варіації 6.226957179480492

# %%
df_climate.head()
# Out:
#               Date  Decimal Date  Average  Interpolated  Trend  Number of Days
# 1958-03  1958.2027        315.71   314.44            -1  -9.99           -0.99
# 1958-04  1958.2877        317.45   315.16            -1  -9.99           -0.99
# 1958-05  1958.3699        317.51   314.69            -1  -9.99           -0.99
# 1958-06  1958.4548        317.27   315.15            -1  -9.99           -0.99
# 1958-07  1958.5370        315.87   315.20            -1  -9.99           -0.99

# %%
# Обираємо числові стовпці для аналізу
wine_feature = 'alcohol'
climate_feature = 'Interpolated'

# %%
# Обчислення описових статистик
wine_stats = {
    "Mean": df_wine[wine_feature].mean(),
    "Median": np.median(df_wine[wine_feature]),
    "Variance": np.var(df_wine[wine_feature]),
    "Std Dev": np.std(df_wine[wine_feature]),
    "Skewness": skew(df_wine[wine_feature]),
    "Kurtosis": kurtosis(df_wine[wine_feature])
}

# %%
climate_stats = {
    "Mean": df_climate[climate_feature].mean(),
    "Median": np.median(df_climate[climate_feature]),
    "Variance": np.var(df_climate[climate_feature]),
    "Std Dev": np.std(df_climate[climate_feature]),
    "Skewness": skew(df_climate[climate_feature]),
    "Kurtosis": kurtosis(df_climate[climate_feature])
}

# %%
# Вивід статистичних показників
print("Wine Dataset Statistics")
for key, value in wine_stats.items():
    print(f"{key}: {value:.4f}")
# Out:
# Wine Dataset Statistics
# Mean: 13.0006
# Median: 13.0500
# Variance: 0.6554
# Std Dev: 0.8095
# Skewness: -0.0510
# Kurtosis: -0.8623

# %%
print("\nClimate Data Statistics")
for key, value in climate_stats.items():
    print(f"{key}: {value:.4f}")
# Out:
# Climate Data Statistics
# Mean: 19.0959
# Median: 25.0000
# Variance: 142.3383
# Std Dev: 11.9306
# Skewness: -0.9385
# Kurtosis: -0.8542

# %%
# Побудова гістограми для Wine Dataset
plt.figure(figsize=(10, 5))
sns.histplot(df_wine[wine_feature], bins=15, kde=True, color='blue', label='Wine Dataset')
plt.legend()
plt.title("Wine Dataset Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
# Побудова гістограми для Climate Change Dataset
plt.figure(figsize=(10, 5))
sns.histplot(df_climate[climate_feature], bins=15, kde=True, color='red', label='Climate Change Dataset', alpha=0.7)
plt.legend()
plt.title("Climate Change Dataset Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
# Побудова радіальної діаграми
def plot_radial_chart(data, feature_name):
    angles = np.linspace(0, 2 * np.pi, len(data), endpoint=False)
    stats_values = list(data.values())
    stats_values.append(stats_values[0])  # Замкнути діаграму
    angles = np.concatenate((angles, [angles[0]]))

    plt.figure(figsize=(6, 6))
    ax = plt.subplot(111, polar=True)
    ax.plot(angles, stats_values, 'o-', linewidth=2)
    ax.fill(angles, stats_values, alpha=0.25)
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(data.keys(), fontsize=10)
    plt.title(f'Radial Chart for {feature_name}')
    plt.show()

# %%
plot_radial_chart(wine_stats, wine_feature)

# %%
plot_radial_chart(climate_stats, climate_feature)
